# %%
# use any dataset link and download the file-
#LINK=  kaggle datasets download -d amritharj/ipl-teamwise-dataset
# this dataset is  performance of teamwise ipl 
#Sl. No.
#Team 
#Home ground
#City 
#Debut
#Total plays
#Wins
#Lost
#Tied
#Tie + W-Number of tied matches won
#Tie + L- Number of tied matches lost
#No Result
#Winning Percentage
#Total title wins
#No. of seasons played
#Captain
#Head coach
#Highest score
# for this data set having 18 attributes and 5 Object, 12 numerical,1 float value.
# i choose this dataset because its easy to understand and vitualize the performance of each team in the IPL.
#  its depend on the teamwise performace team, how many total plays,wins,lost,higheat score,so it will anlysing useing differnet graph

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cricket=pd.read_csv('ipl.csv')

# %%
cricket.head()
# Out:
#    Sl. No. Team                Home ground       City  Debut  Total plays  \
# 0        1  CSK  M. A. Chidambaram Stadium    Chennai   2008          209
# 1        2   DC               Arun Stadium  New Delhi   2008          224
# 2        3   GT      Narendra Modi Stadium  Ahmedabad   2022           16
# 3        4  KKR               Eden Gardens    Kolkata   2008          223
# 4        5  LSG             BRSABV Stadium    Lucknow   2022           15
#
#    Wins  Lost  Tied  Tie + W  Tie + L  No Result  Winning Percentage  \
# 0   121    86     0        0        1          1               58.41
# 1   100   118     0        3        1          2               45.94
# 2    12     4     0        0        0          0               75.00
# 3   113   106     0        1        3          0               51.56
# 4     9     6     0        0        0          0               60.00
#
#    Total title wins  No. of seasons played      Captain    Head coach  \
# ...

# %%
cricket.shape
# Out:
# (10, 18)

# %%
cricket
# Out:
#    Sl. No. Team                Home ground       City  Debut  Total plays  \
# 0        1  CSK  M. A. Chidambaram Stadium    Chennai   2008          209
# 1        2   DC               Arun Stadium  New Delhi   2008          224
# 2        3   GT      Narendra Modi Stadium  Ahmedabad   2022           16
# 3        4  KKR               Eden Gardens    Kolkata   2008          223
# 4        5  LSG             BRSABV Stadium    Lucknow   2022           15
# 5        6   MI           Wankhede Stadium     Mumbai   2008          231
# 6        7   PK           Inderjit Stadium     Mohali   2008          218
# 7        8   RR              Sawai Stadium     Jaipur   2008          192
# 8        9  RCB     M. Chinnaswamy Stadium  Bangalore   2008          227
# 9       10   SH       Rajiv Gandhi Stadium  Hyderabad   2013          152
#
#    Wins  Lost  Tied  Tie + W  Tie + L  No Result  Winning Percentage  \
# 0   121    86     0        0        1          1               58.41
# ...

# %%
#tabel form which year debut

# %%
cricket.Debut.value_counts()
# Out:
# 2008    7
# 2022    2
# 2013    1
# Name: Debut, dtype: int64

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sl. No.                10 non-null     int64
#  1   Team                   10 non-null     object
#  2   Home ground            10 non-null     object
#  3   City                   10 non-null     object
#  4   Debut                  10 non-null     int64
#  5   Total plays            10 non-null     int64
#  6   Wins                   10 non-null     int64
#  7   Lost                   10 non-null     int64
#  8   Tied                   10 non-null     int64
#  9   Tie + W                10 non-null     int64
#  10  Tie + L                10 non-null     int64
#  11  No Result              10 non-null     int64
#  12  Winning Percentage     10 non-null     float64
#  13  Total title wins       10 non-null     int64
#  14  No. of seasons played  10 non-null     int64
# ...

# %%
# bar plot between 2 different categories= in this gragh  see the total 10 teams and in that MI team is wins more which is 129 and second is CSK team win 121 and 3rd =KKR
sns.barplot(cricket['Team'], cricket['Wins'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='Wins'>

# %%
cricket.Debut.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Debut'>

# %%
# for single column distrubution we can use distplot

# %%
sns.distplot(cricket['Wins'])
# Out:
# <AxesSubplot:xlabel='Wins', ylabel='Density'>

# %%
#
sns.jointplot(cricket['Wins'],cricket['Highest score'], kind="kde")
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# pair wise vitualize dataset here are 3 varible sr. no, wins,highest score 3 data accordigly
# TEAM WISE SR.NO WISE showing which team have highest score and which team have more wins= Highest score is 263 and 129 is highest wins
sns.pairplot(cricket[['Team','Wins','Highest score']])

# %%
#
sns.stripplot(cricket['Tie + W'],cricket['Tie + L'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tie + W', ylabel='Tie + L'>

# %%
# using boxplot x axis is team and y-axis is total title wins =highest win team  is MI and csk,the highest score 263 which is RCB TEAM

sns.boxplot(cricket['Team'],cricket['Total title wins'],cricket['Highest score'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='Total title wins'>

# %%
#using pontplot CSK play 209 and wins 121
# DC toatl plays 224 and wins 100
#GT toatl plays 16 and wins 12
#KKR total plays 223 and wins 113
# LSG total plays 15 and wins 9
# MI total play 231 and wins 219 
# PK total play 218 and wins 98
#RR total play 192 and wins 94
# RCB total play 227 and wins 107
# SH total plays 152 and wins 74
sns.pointplot(cricket['Team'],cricket['Wins'],cricket['Total plays'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='Wins'>

# %%
sns.countplot(cricket['Winning Percentage'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Winning Percentage', ylabel='count'>

# %%
# LOST AND WINS DATA TEAMWISE
# CSK WINS 121 LOST 86
# DC WINS 100 LOST 118
# GT wins 12 lost 4
#KKR wins 106 and lost 106 
# LSG wins 15 and lost 6
#MI wins 129 lost 96
# pk wins 98 lost 116
#RR wins 94 and lost 93
# RCB WINS 107 AND LOST 113
# SH WINS 74 AND LOST 74 

sns.pointplot(cricket['Team'],cricket['Wins'],cricket['Lost'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='Wins'>

# %%
# according to captain and captain wise winning percentage 
# 1.GST =Hardik p= 75%
# 2.LSG-KL rahul=60%
# 3.CSK =M.S dhoni= 58%
# 4. MI =Rohit sharma= 56%
sns.pointplot(cricket['Team'],cricket['Winning Percentage'],cricket['Captain'])
# Out:
# C:\Users\CITS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Team', ylabel='Winning Percentage'>

# %%
# as per vitualization teamwise perforamce is GT team is highest according to wins matches and lost and winning percentages 
# 2nd high performace is LGK  team hich is 60% 
#3r performance is CSK team which is 58%
# 4th team is MI chich 56 %
 # poor performance is PK team
